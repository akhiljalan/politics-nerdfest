# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Ideology
#
# Let's look at ideological drift.

# %%
senate_ideology_df = pd.read_csv('data/ideological_positions_senate_committees.csv', index_col=1)
house_ideology_df = pd.read_csv('data/ideological_positions_house_committees.csv', index_col=1)

# %%
senate_ideology_df['Committee'].value_counts()
# Out:
# Armed Services                              102
# Rules & Administration                      102
# Budget                                      102
# Judiciary                                   102
# Banking, Housing, & Urban Affairs           102
# Appropriations                              102
# Energy & Natural Resources                  102
# Homeland Security & Governmental Affairs    102
# Health, Education, Labor, & Pensions        102
# Foreign Relations                           102
# Environment & Public Works                  102
# Small Business & Entrepreneurship           102
# Commerce, Science, & Transportation         102
# Chamber average                             102
# Veterans Affairs                            102
# Finance                                     102
# Agriculture, Nutrition, & Forestry          102
# Name: Committee, dtype: int64

# %%
house_ideology_df['Committee'].value_counts()
# Out:
# Armed Services                     102
# Financial Services                 102
# Agriculture                        102
# Science, Space & Technology        102
# Budget                             102
# Judiciary                          102
# Small Business                     102
# Appropriations                     102
# Ways & Means                       102
# Merchant Marine and Fisheries      102
# District of Columbia               102
# Post Office and Civil Service      102
# Transportation & Infrastructure    102
# Chamber average                    102
# Natural Resources                  102
# Rules                              102
# Veterans Affairs                   102
# House Administration               102
# Ethics                             102
# Oversight & Government Reform      102
# Education & the Workforce          102
# Energy and Commerce                102
# Homeland Security                  102
# Foreign Affairs                    102
# ...

# %%
house_ideology_df.loc[2013]
# Out:
#       Congress        Party                        Committee Position
# Year
# 2013       113          All                      Agriculture    0.249
# 2013       113    Democrats                      Agriculture   -0.287
# 2013       113  Republicans                      Agriculture      0.7
# 2013       113          All                   Appropriations    0.128
# 2013       113    Democrats                   Appropriations   -0.386
# 2013       113  Republicans                   Appropriations    0.568
# 2013       113          All                   Armed Services    0.215
# 2013       113    Democrats                   Armed Services   -0.302
# 2013       113  Republicans                   Armed Services    0.641
# 2013       113          All                           Budget    0.221
# 2013       113    Democrats                           Budget    -0.43
# 2013       113  Republicans                           Budget    0.807
# ...

# %%
house_ideology_df[house_ideology_df.index > 2000]
# Out:
#       Congress        Party        Committee Position
# Year
# 2001       107          All      Agriculture    0.165
# 2003       108          All      Agriculture    0.152
# 2005       109          All      Agriculture    0.177
# 2007       110          All      Agriculture    0.124
# 2009       111          All      Agriculture    0.112
# 2011       112          All      Agriculture    0.268
# 2013       113          All      Agriculture    0.249
# 2001       107    Democrats      Agriculture   -0.257
# 2003       108    Democrats      Agriculture   -0.243
# 2005       109    Democrats      Agriculture   -0.215
# 2007       110    Democrats      Agriculture   -0.211
# 2009       111    Democrats      Agriculture   -0.195
# 2011       112    Democrats      Agriculture     -0.3
# 2013       113    Democrats      Agriculture   -0.287
# 2001       107  Republicans      Agriculture    0.462
# 2003       108  Republicans      Agriculture    0.473
# ...

# %%
for row in house_ideology_df[house_ideology_df['Party'] != 'All'].loc[1947]:
# Out:
# Congress
# Party
# Committee
# Position

# %%
house_2013 = house_ideology_df[house_ideology_df['Party'] != 'All'].loc[2013]
house_2013.applymap(lambda string: Null if string == 'n.a.' else string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a1057ba5bd42> in <module>()
#       1 house_2013 = house_ideology_df[house_ideology_df['Party'] != 'All'].loc[2013]
# ----> 2 house_2013.applymap(lambda string: Null if string == 'n.a.' else string)
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in applymap(self, func)
#    5043             return lib.map_infer(x.asobject, func)
#    5044
# -> 5045         return self.apply(infer)
#    5046
#    5047     # ----------------------------------------------------------------------
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4852                         f, axis,
#    4853                         reduce=reduce,
# -> 4854                         ignore_failures=ignore_failures)
#    4855             else:
# ...

# %%
house_2013
# Out:
#       Congress        Party                        Committee Position
# Year
# 2013       113    Democrats                      Agriculture   -0.287
# 2013       113  Republicans                      Agriculture      0.7
# 2013       113    Democrats                   Appropriations   -0.386
# 2013       113  Republicans                   Appropriations    0.568
# 2013       113    Democrats                   Armed Services   -0.302
# 2013       113  Republicans                   Armed Services    0.641
# 2013       113    Democrats                           Budget    -0.43
# 2013       113  Republicans                           Budget    0.807
# 2013       113    Democrats             District of Columbia     n.a.
# 2013       113  Republicans             District of Columbia     n.a.
# 2013       113    Democrats        Education & the Workforce   -0.409
# 2013       113  Republicans        Education & the Workforce    0.745
# ...

# %%
house_2013 = house_2013.sort_values(by='Position')

# %%
plt.bar?

# %%
house_2013['Position'].iloc[-16:-6]
# Out:
# Year
# 2013    0.735
# 2013    0.745
# 2013     0.75
# 2013    0.776
# 2013    0.802
# 2013    0.807
# 2013    0.809
# 2013    0.822
# 2013    0.824
# 2013    0.828
# Name: Position, dtype: object

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
plt.bar(np.linspace(1, 20, num=20), pd.concat((house_2013['Position'].iloc[-16:-6], house_2013['Position'].iloc[:10])))
# Out:
# <Container object of 20 artists>

# %%
house_2013 = house_2013[house_2013['Position'] != 'n.a.']

# %% [markdown]
# ### Comittee Differences

# %%
# %xmode verbose
plt.figure(figsize=(12, 8))
pd.to_numeric(house_2013['Position'])
sns.barplot(x='Committee', y='Position', hue='Party', data=house_2013, palette=['Blue', 'Red']);
plt.xticks(rotation=90);
plt.title('Ideological Differences in House Committees (2013)');
# Out:
# Exception reporting mode: Verbose
# /Users/akhiljalan/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
senate_2013 = senate_ideology_df.loc[2013]
senate_2013 = senate_2013[senate_2013['Party'] != 'All members']
senate_2013 = senate_2013[senate_2013['Position'] != 'n.a.']
senate_2013['Position'] = pd.to_numeric(senate_2013['Position'])
senate_2013.sort_values(by='Position')

plt.figure(figsize=(12, 8))
sns.barplot(x='Committee', y='Position', hue='Party', data=senate_2013, palette=['Blue', 'Red']);
plt.xticks(rotation=90);
plt.title('Ideological Differences in Senate Committees (2013)');
# Out:
# /Users/akhiljalan/anaconda/lib/python3.6/site-packages/seaborn/categorical.py:1508: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %% [markdown]
# # Midterm Seat Losses

# %%
house_seats_df = pd.read_csv('data/house_seats_by_party.csv')
midterm_losses_df = pd.read_csv('data/pres_party_midterm_losses.csv')
